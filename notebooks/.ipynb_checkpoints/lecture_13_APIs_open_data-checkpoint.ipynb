# %% [markdown]
# # CYPLAN255
# ### Urban Informatics and Visualization

# %% [markdown]
# # Lecture 13 -- APIs and Beyond <img src="https://i.imgur.com/HMHNjAq.jpg" width=550 align='right' title="Scottish child actress, Binkie Stuart (1932 - 2001) hand in hand with a penguin during a visit to London Zoo, 15th April 1937. (Photo by Fox Photos/Hulton Archive/Getty Images)">
# ******
# March 11, 2024

# %% [markdown]
# # Agenda
# 1. Announcements
# 2. Review: APIs + JSON
# 2. Geocoding APIs
# 3. The Census API
# 4. Summary
# 5. For next time
# 6. Questions

# %% [markdown]
# # 1. Announcements

# %% [markdown]
# - Assignment 4 (project proposal + initial analysis) due March 10
# - Final Project description released tonight
# - Meiqing's GitHub Pages tutorial posted on bCourses
# - How far we've come

# %% [markdown]
# ## How Far We've Come
#
# 1. ~Fundamentals of Programming~
# 1. ~Intro to Data Analysis in Python~
# 1. ~Intro to Data Visualization~
# 1. APIs + Open Data
# 1. Working with Geospatial Data
# 1. Visualizing Spatial Data
# 1. Statistical Analysis + Machine Learning

# %% [markdown]
# # 2. Review: APIs + JSON

# %% [markdown]
# So far we've seen how you can use an API to download data stored as a .json file in some static location. That's cool, but ultimately not that different from clicking a link and downloading a file to your desktop. It also presumes you know the URL you want ahead of time, and that you want to download the entire file.
#
# Today we're going to be seeing how you can use APIs to interact with _services_, i.e. APIs that perform operations and generate the data you want on demand. To continue with the restaurant analogy, we started off ordering fast food burgers, but now we're ready for the tasting menu at Chez Panisse.

# %% [markdown]
# <img src="https://i.kym-cdn.com/photos/images/original/001/474/943/b12.jpg" width=400>

# %% [markdown]
# But before we get there, let's quickly review what we've learned so far by checking out the USGS real-time earthquake data API.
#
# ### 2.1. USGS real-time earthquake feeds
#
# This is an API for near-real-time data about earthquakes. Data is provided in JSON format over the web. No authentication is needed, and there's no way to customize the output. Instead, the API has a separate endpoint for each permutation of the data that users might want.
#
# **API documentation:**
# http://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson.php
#
# **Sample API endpoint, for magnitude 4.5+ earthquakes in past day:**
# http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_day.geojson

# %% [markdown]
# We'll start by querying the endpoint for magnitude 2.5+ quakes from the past week:

# %%
import pandas as pd
import json    
import requests
import pprint
pp = pprint.PrettyPrinter

endpoint_url = "http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson"
response = requests.get(endpoint_url)
print(response.text[:500])
# Out:
# {"type":"FeatureCollection","metadata":{"generated":1710040517000,"url":"https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson","title":"USGS Magnitude 2.5+ Earthquakes, Past Week","status":200,"api":"1.10.3","count":261},"features":[{"type":"Feature","properties":{"mag":2.49,"place":"3 km S of Magas Arriba, Puerto Rico","time":1710036846200,"updated":1710037574360,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/pr71442638","detail":"https://earthquake.usg

# %% [markdown]
# It looks like the results are a string with JSON-formatted data inside, so we'll parse the string into a Python dictionary using `json.loads()`:

# %%
data = json.loads(response.text)
data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1710040517000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson',
#   'title': 'USGS Magnitude 2.5+ Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 261},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.49,
#     'place': '3 km S of Magas Arriba, Puerto Rico',
#     'time': 1710036846200,
#     'updated': 1710037574360,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442638',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442638.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'pr',
#     'code': '71442638',
#     'ids': ',pr71442638,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.04526,
#     'rms': 0.12,
#     'gap': 153,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 3 km S of Magas Arriba, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.7626666666667, 17.9838333333333, 12.72]},
#    'id': 'pr71442638'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.46,
#     'place': '7 km WSW of Petrolia, CA',
#     'time': 1710032405510,
#     'updated': 1710036784349,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc74014796',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc74014796.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': 1.932,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 184,
#     'net': 'nc',
#     'code': '74014796',
#     'ids': ',nc74014796,us7000m4gr,',
#     'sources': ',nc,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,shakemap,',
#     'nst': 23,
#     'dmin': 0.02808,
#     'rms': 0.15,
#     'gap': 235,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 7 km WSW of Petrolia, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-124.3691635, 40.3078346, 29.74]},
#    'id': 'nc74014796'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '55 km NE of Kobuk, Alaska',
#     'time': 1710031596753,
#     'updated': 1710031811381,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak02437rw8bm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02437rw8bm.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '02437rw8bm',
#     'ids': ',ak02437rw8bm,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.8,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 55 km NE of Kobuk, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-155.8861, 67.2212, 30]},
#    'id': 'ak02437rw8bm'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': 'south of the Fiji Islands',
#     'time': 1710016648002,
#     'updated': 1710025806040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4g5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4g5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000m4g5',
#     'ids': ',us7000m4g5,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 39,
#     'dmin': 5.231,
#     'rms': 0.63,
#     'gap': 99,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - south of the Fiji Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [179.8302, -24.4128, 523.847]},
#    'id': 'us7000m4g5'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '16 km E of Calama, Chile',
#     'time': 1710014333172,
#     'updated': 1710028511040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4fz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4fz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000m4fz',
#     'ids': ',us7000m4fz,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.743,
#     'rms': 0.58,
#     'gap': 66,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 16 km E of Calama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.7627, -22.4382, 128.192]},
#    'id': 'us7000m4fz'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '128 km W of Valparaíso, Chile',
#     'time': 1710012191939,
#     'updated': 1710027240040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4ft',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4ft.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '7000m4ft',
#     'ids': ',us7000m4ft,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 56,
#     'dmin': 1.146,
#     'rms': 0.69,
#     'gap': 132,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 128 km W of Valparaíso, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-72.9885, -33.241, 10]},
#    'id': 'us7000m4ft'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.61,
#     'place': '127 km N of Hatillo, Puerto Rico',
#     'time': 1710007519900,
#     'updated': 1710008809184,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024069000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024069000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 200,
#     'net': 'pr',
#     'code': '2024069000',
#     'ids': ',pr2024069000,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 9,
#     'dmin': 1.4869,
#     'rms': 0.28,
#     'gap': 311,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 127 km N of Hatillo, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.822, 19.6391, 71]},
#    'id': 'pr2024069000'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '41 km ENE of La Tirana, Chile',
#     'time': 1710002591276,
#     'updated': 1710016933119,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4fd',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4fd.geojson',
#     'felt': 3,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000m4fd',
#     'ids': ',us7000m4fd,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.52,
#     'rms': 0.6,
#     'gap': 67,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 41 km ENE of La Tirana, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.2976, -20.182, 111.057]},
#    'id': 'us7000m4fd'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.48000002,
#     'place': '9 km E of Pāhala, Hawaii',
#     'time': 1710001073920,
#     'updated': 1710001175570,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv74132396',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv74132396.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'hv',
#     'code': '74132396',
#     'ids': ',hv74132396,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 46,
#     'dmin': 0.0764,
#     'rms': 0.119999997,
#     'gap': 164,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 9 km E of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.389007568359, 19.1881675720215, 29.5599994659424]},
#    'id': 'hv74132396'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.57,
#     'place': '3 km SSW of Indios, Puerto Rico',
#     'time': 1709995725270,
#     'updated': 1709997564040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442573',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442573.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 102,
#     'net': 'pr',
#     'code': '71442573',
#     'ids': ',pr71442573,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.04745,
#     'rms': 0.1,
#     'gap': 166,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 3 km SSW of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8298333333333, 17.9688333333333, 11.15]},
#    'id': 'pr71442573'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.83,
#     'place': '5 km E of Elgin, South Carolina',
#     'time': 1709994421180,
#     'updated': 1710040102790,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/se60572666',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/se60572666.geojson',
#     'felt': 956,
#     'cdi': 3.6,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 467,
#     'net': 'se',
#     'code': '60572666',
#     'ids': ',se60572666,us7000m4eq,',
#     'sources': ',se,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.04022,
#     'rms': 0.33,
#     'gap': 63,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 5 km E of Elgin, South Carolina'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-80.7311666666667, 34.1638333333333, 2.86]},
#    'id': 'se60572666'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '18 km NNE of Stanley, Idaho',
#     'time': 1709990293293,
#     'updated': 1710000119040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4e9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4e9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'us',
#     'code': '7000m4e9',
#     'ids': ',us7000m4e9,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.264,
#     'rms': 0.9,
#     'gap': 102,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 18 km NNE of Stanley, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-114.8308, 44.3695, 10]},
#    'id': 'us7000m4e9'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '273 km SSE of Akhiok, Alaska',
#     'time': 1709989638297,
#     'updated': 1709994655040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4ed',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4ed.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'us',
#     'code': '7000m4ed',
#     'ids': ',us7000m4ed,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 39,
#     'dmin': 2.942,
#     'rms': 0.76,
#     'gap': 242,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 273 km SSE of Akhiok, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.8124, 54.8795, 12.389]},
#    'id': 'us7000m4ed'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '115 km WNW of Aykol, China',
#     'time': 1709987744230,
#     'updated': 1709991015040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4e5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4e5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000m4e5',
#     'ids': ',us7000m4e5,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.32,
#     'rms': 1.28,
#     'gap': 115,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 115 km WNW of Aykol, China'},
#    'geometry': {'type': 'Point', 'coordinates': [78.7931, 41.2002, 10]},
#    'id': 'us7000m4e5'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': '238 km E of Levuka, Fiji',
#     'time': 1709985667624,
#     'updated': 1709993052674,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4e2',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4e2.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 1.435,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '7000m4e2',
#     'ids': ',us7000m4e2,',
#     'sources': ',us,',
#     'types': ',losspager,origin,phase-data,shakemap,',
#     'nst': 60,
#     'dmin': 3.351,
#     'rms': 0.68,
#     'gap': 78,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.5 - 238 km E of Levuka, Fiji'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-178.4362, -17.9633, 576.728]},
#    'id': 'us7000m4e2'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '48 km NW of San Antonio, Puerto Rico',
#     'time': 1709982937330,
#     'updated': 1709984931550,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442538',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442538.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'pr',
#     'code': '71442538',
#     'ids': ',pr71442538,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 30,
#     'dmin': 0.4102,
#     'rms': 0.32,
#     'gap': 218,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 48 km NW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.4161666666667, 18.8141666666667, 8]},
#    'id': 'pr71442538'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '134 km SW of San Pedro de Atacama, Chile',
#     'time': 1709976148848,
#     'updated': 1709977008040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4de',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4de.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000m4de',
#     'ids': ',us7000m4de,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 30,
#     'dmin': 1.193,
#     'rms': 1.09,
#     'gap': 71,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 134 km SW of San Pedro de Atacama, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.9994, -23.8804, 91.813]},
#    'id': 'us7000m4de'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '47 km SSW of Ollagüe, Chile',
#     'time': 1709974637562,
#     'updated': 1709990910040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4db',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4db.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000m4db',
#     'ids': ',us7000m4db,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 42,
#     'dmin': 1.186,
#     'rms': 1.11,
#     'gap': 57,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 47 km SSW of Ollagüe, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.3838, -21.6368, 123.727]},
#    'id': 'us7000m4db'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.74,
#     'place': '3 km S of Independence, CA',
#     'time': 1709971542370,
#     'updated': 1709977162295,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40684256',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40684256.geojson',
#     'felt': 2,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'ci',
#     'code': '40684256',
#     'ids': ',ci40684256,nc74014301,nn00874427,',
#     'sources': ',ci,nc,nn,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 35,
#     'dmin': 0.02246,
#     'rms': 0.28,
#     'gap': 83,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 3 km S of Independence, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.1969986, 36.7799988, 12.44]},
#    'id': 'ci40684256'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.38,
#     'place': '37 km NNW of San Antonio, Puerto Rico',
#     'time': 1709970365680,
#     'updated': 1709971932600,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442518',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442518.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 176,
#     'net': 'pr',
#     'code': '71442518',
#     'ids': ',us7000m4d1,pr71442518,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': 0.3243,
#     'rms': 0.25,
#     'gap': 263,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 37 km NNW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.2233333333333, 18.814, 17.92]},
#    'id': 'pr71442518'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '66 km ENE of Cordova, Alaska',
#     'time': 1709967643947,
#     'updated': 1709971595040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak02436892p6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02436892p6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '02436892p6',
#     'ids': ',us7000m4cw,ak02436892p6,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.44,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 66 km ENE of Cordova, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-144.6319, 60.7574, 4.5]},
#    'id': 'ak02436892p6'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '11 km NNW of Virginia City, Nevada',
#     'time': 1709965645425,
#     'updated': 1710036545252,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00874424',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00874424.geojson',
#     'felt': 296,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 270,
#     'net': 'nn',
#     'code': '00874424',
#     'ids': ',nn00874424,us7000m4ct,',
#     'sources': ',nn,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.057,
#     'rms': 0.1621,
#     'gap': 40.53,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 11 km NNW of Virginia City, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.6925, 39.4113, 8.5]},
#    'id': 'nn00874424'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '42 km S of Shizunai-furukawachō, Japan',
#     'time': 1709961505349,
#     'updated': 1709976513836,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4cj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4cj.geojson',
#     'felt': 2,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 370,
#     'net': 'us',
#     'code': '7000m4cj',
#     'ids': ',us7000m4cj,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 98,
#     'dmin': 0.612,
#     'rms': 0.53,
#     'gap': 60,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 42 km S of Shizunai-furukawachō, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [142.3401, 41.9544, 62.298]},
#    'id': 'us7000m4cj'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '84 km ENE of Nagqu, China',
#     'time': 1709961466850,
#     'updated': 1709963292040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4ck',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4ck.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000m4ck',
#     'ids': ',us7000m4ck,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 45,
#     'dmin': 7.698,
#     'rms': 0.61,
#     'gap': 76,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 84 km ENE of Nagqu, China'},
#    'geometry': {'type': 'Point', 'coordinates': [92.7963, 31.8953, 10]},
#    'id': 'us7000m4ck'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.48,
#     'place': '10 km NE of Hawaiian Ocean View, Hawaii',
#     'time': 1709961020200,
#     'updated': 1709961178940,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv74132131',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv74132131.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'hv',
#     'code': '74132131',
#     'ids': ',hv74132131,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': 0.05819,
#     'rms': 0.310000002,
#     'gap': 211,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 10 km NE of Hawaiian Ocean View, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.693664550781, 19.1389999389648, 7.67999982833862]},
#    'id': 'hv74132131'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.76,
#     'place': '17 km E of Willows, CA',
#     'time': 1709960239020,
#     'updated': 1709960333514,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc74014231',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc74014231.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 117,
#     'net': 'nc',
#     'code': '74014231',
#     'ids': ',nc74014231,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.1191,
#     'rms': 0.08,
#     'gap': 72,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 17 km E of Willows, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.0003357, 39.4944992, 26.77]},
#    'id': 'nc74014231'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '20 km NNE of Stanley, Idaho',
#     'time': 1709959073036,
#     'updated': 1709995512120,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4c9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4c9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'us',
#     'code': '7000m4c9',
#     'ids': ',mb90042843,us7000m4c9,',
#     'sources': ',mb,us,',
#     'types': ',origin,phase-data,',
#     'nst': 32,
#     'dmin': 0.287,
#     'rms': 1.22,
#     'gap': 31,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 20 km NNE of Stanley, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-114.8642, 44.3928, 10]},
#    'id': 'us7000m4c9'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.46,
#     'place': '8 km ENE of Verden, Oklahoma',
#     'time': 1709957495809,
#     'updated': 1710039596969,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2024euon',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ok2024euon.geojson',
#     'felt': 3,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 94,
#     'net': 'ok',
#     'code': '2024euon',
#     'ids': ',ok2024euon,',
#     'sources': ',ok,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 61,
#     'dmin': 0.1211827844,
#     'rms': 0.8455995103,
#     'gap': 46.01765442,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 8 km ENE of Verden, Oklahoma'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-98.00218201, 35.11210251, 1.828979135]},
#    'id': 'ok2024euon'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.66,
#     'place': '5 km WSW of Guánica, Puerto Rico',
#     'time': 1709955607370,
#     'updated': 1709956965230,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442483',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442483.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 109,
#     'net': 'pr',
#     'code': '71442483',
#     'ids': ',pr71442483,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 23,
#     'dmin': 0.04899,
#     'rms': 0.17,
#     'gap': 202,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 5 km WSW of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.9531666666667, 17.9475, 7.2]},
#    'id': 'pr71442483'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '60 km S of Whites City, New Mexico',
#     'time': 1709949753310,
#     'updated': 1709979868105,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024eukg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024eukg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'tx',
#     'code': '2024eukg',
#     'ids': ',us7000m4bm,tx2024eukg,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.1,
#     'rms': 0.2,
#     'gap': 63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 60 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.371, 31.628, 6.7151]},
#    'id': 'tx2024eukg'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.49000001,
#     'place': '6 km S of Pāhala, Hawaii',
#     'time': 1709948138320,
#     'updated': 1709950096875,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv74131996',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv74131996.geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'hv',
#     'code': '74131996',
#     'ids': ',hv74131996,',
#     'sources': ',hv,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 39,
#     'dmin': 0.01433,
#     'rms': 0.159999996,
#     'gap': 168,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 6 km S of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.475006103516, 19.1478328704834, 31.4400005340576]},
#    'id': 'hv74131996'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '54 km NW of Toyah, Texas',
#     'time': 1709943169208,
#     'updated': 1709944418040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024eugq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024eugq.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'tx',
#     'code': '2024eugq',
#     'ids': ',us7000m4b5,tx2024eugq,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 21,
#     'dmin': 0.1,
#     'rms': 0.2,
#     'gap': 61,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 54 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.188, 31.674, 7.2791]},
#    'id': 'tx2024eugq'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.03,
#     'place': '18 km WSW of La Jolla, CA',
#     'time': 1709932181170,
#     'updated': 1710032523004,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40683864',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40683864.geojson',
#     'felt': 131,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 191,
#     'net': 'ci',
#     'code': '40683864',
#     'ids': ',ci40683864,us7000m4a5,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 74,
#     'dmin': 0.1908,
#     'rms': 0.21,
#     'gap': 128,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 18 km WSW of La Jolla, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.4613333, 32.7955, 15.81]},
#    'id': 'ci40683864'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.82,
#     'place': '32 km ENE of Cruz Bay, U.S. Virgin Islands',
#     'time': 1709930897350,
#     'updated': 1710004200040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024068002',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024068002.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 224,
#     'net': 'pr',
#     'code': '2024068002',
#     'ids': ',us7000m49w,pr2024068002,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.4582,
#     'rms': 0.47,
#     'gap': 341,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 32 km ENE of Cruz Bay, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.5036, 18.422, 100]},
#    'id': 'pr2024068002'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.01,
#     'place': '40 km NNW of San Antonio, Puerto Rico',
#     'time': 1709929318500,
#     'updated': 1709932000100,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442428',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442428.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 139,
#     'net': 'pr',
#     'code': '71442428',
#     'ids': ',pr71442428,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.3769,
#     'rms': 0.08,
#     'gap': 202,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 40 km NNW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.2881666666667, 18.8068333333333, 8.75]},
#    'id': 'pr71442428'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.45,
#     'place': '8 km SSE of Guánica, Puerto Rico',
#     'time': 1709928693180,
#     'updated': 1709932973170,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442438',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442438.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 92,
#     'net': 'pr',
#     'code': '71442438',
#     'ids': ',pr71442438,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': 0.07614,
#     'rms': 0.18,
#     'gap': 237,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 8 km SSE of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8796666666667, 17.8985, 6.54]},
#    'id': 'pr71442438'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '5 km SW of Ichinomiya, Japan',
#     'time': 1709926001934,
#     'updated': 1709998523040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m494',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m494.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000m494',
#     'ids': ',us7000m494,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 90,
#     'dmin': 2.107,
#     'rms': 0.77,
#     'gap': 120,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 5 km SW of Ichinomiya, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [140.3377, 35.3326, 27.849]},
#    'id': 'us7000m494'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '81 km SSE of Hengchun, Taiwan',
#     'time': 1709924286208,
#     'updated': 1709938270040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m48w',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m48w.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000m48w',
#     'ids': ',us7000m48w,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 95,
#     'dmin': 1.495,
#     'rms': 0.75,
#     'gap': 110,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 81 km SSE of Hengchun, Taiwan'},
#    'geometry': {'type': 'Point', 'coordinates': [121.016, 21.3162, 10]},
#    'id': 'us7000m48w'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.45,
#     'place': '11 km S of Guánica, Puerto Rico',
#     'time': 1709922457910,
#     'updated': 1709925406240,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442413',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442413.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 92,
#     'net': 'pr',
#     'code': '71442413',
#     'ids': ',pr71442413,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.1092,
#     'rms': 0.19,
#     'gap': 247,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 11 km S of Guánica, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.9108333333333, 17.8695, 10.84]},
#    'id': 'pr71442413'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.45,
#     'place': '47 km NNE of Cruz Bay, U.S. Virgin Islands',
#     'time': 1709922238420,
#     'updated': 1709938186040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024068001',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024068001.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 183,
#     'net': 'pr',
#     'code': '2024068001',
#     'ids': ',us7000m48u,pr2024068001,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.5048,
#     'rms': 0.38,
#     'gap': 319,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 47 km NNE of Cruz Bay, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.6126, 18.722, 24]},
#    'id': 'pr2024068001'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '15 km WNW of Rancagua, Chile',
#     'time': 1709921568665,
#     'updated': 1709935795040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m48k',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m48k.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '7000m48k',
#     'ids': ',us7000m48k,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.297,
#     'rms': 0.28,
#     'gap': 102,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 15 km WNW of Rancagua, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.9055, -34.1335, 82.458]},
#    'id': 'us7000m48k'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.3,
#     'place': 'south of the Fiji Islands',
#     'time': 1709918515620,
#     'updated': 1709999716040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m486',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m486.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 432,
#     'net': 'us',
#     'code': '7000m486',
#     'ids': ',us7000m486,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 228,
#     'dmin': 4.922,
#     'rms': 0.78,
#     'gap': 22,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.3 - south of the Fiji Islands'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-179.5721, -22.1543, 598.021]},
#    'id': 'us7000m486'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '9 km NNW of Stanley, Idaho',
#     'time': 1709918327170,
#     'updated': 1709929747040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m485',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m485.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'us',
#     'code': '7000m485',
#     'ids': ',mb90042813,us7000m485,',
#     'sources': ',mb,us,',
#     'types': ',origin,phase-data,',
#     'nst': 30,
#     'dmin': 0.211,
#     'rms': 0.59,
#     'gap': 36,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 9 km NNW of Stanley, Idaho'},
#    'geometry': {'type': 'Point', 'coordinates': [-114.9924, 44.2898, 11.178]},
#    'id': 'us7000m485'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.59,
#     'place': '91 km N of Culebra, Puerto Rico',
#     'time': 1709898832720,
#     'updated': 1709900831103,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024068000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024068000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 198,
#     'net': 'pr',
#     'code': '2024068000',
#     'ids': ',pr2024068000,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.8666,
#     'rms': 0.4,
#     'gap': 273,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 91 km N of Culebra, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-65.3461, 19.1303, 26]},
#    'id': 'pr2024068000'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '10 km ESE of Chickasha, Oklahoma',
#     'time': 1709893245850,
#     'updated': 1709964022165,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2024etfe',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ok2024etfe.geojson',
#     'felt': 16,
#     'cdi': 4.9,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 137,
#     'net': 'ok',
#     'code': '2024etfe',
#     'ids': ',ok2024etfe,us7000m449,',
#     'sources': ',ok,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 86,
#     'dmin': 0.08008428473,
#     'rms': 0.24,
#     'gap': 44,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 10 km ESE of Chickasha, Oklahoma'},
#    'geometry': {'type': 'Point', 'coordinates': [-97.828, 35.0185, 7.33]},
#    'id': 'ok2024etfe'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '11 km S of Bullaburra, Australia',
#     'time': 1709891593045,
#     'updated': 1710015197516,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m44b',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m44b.geojson',
#     'felt': 261,
#     'cdi': 4.5,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 306,
#     'net': 'us',
#     'code': '7000m44b',
#     'ids': ',us7000m44b,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 6,
#     'dmin': 1.893,
#     'rms': 0.46,
#     'gap': 201,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 11 km S of Bullaburra, Australia'},
#    'geometry': {'type': 'Point', 'coordinates': [150.427, -33.8349, 8.356]},
#    'id': 'us7000m44b'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '98 km SE of Pondaguitan, Philippines',
#     'time': 1709889106107,
#     'updated': 1709975912951,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m439',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m439.geojson',
#     'felt': 5,
#     'cdi': 3.1,
#     'mmi': 4.146,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 555,
#     'net': 'us',
#     'code': '7000m439',
#     'ids': ',us7000m439,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 109,
#     'dmin': 1.792,
#     'rms': 0.74,
#     'gap': 55,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 98 km SE of Pondaguitan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.8802, 5.8202, 125.036]},
#    'id': 'us7000m439'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '16 km S of Atoka, New Mexico',
#     'time': 1709888058900,
#     'updated': 1709898844659,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m437',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m437.geojson',
#     'felt': 3,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 139,
#     'net': 'us',
#     'code': '7000m437',
#     'ids': ',us7000m437,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 31,
#     'dmin': 0.486,
#     'rms': 0.41,
#     'gap': 100,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 16 km S of Atoka, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.4025, 32.6216, 5]},
#    'id': 'us7000m437'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '75 km N of La Serena, Chile',
#     'time': 1709883645785,
#     'updated': 1709898966365,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m42y',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m42y.geojson',
#     'felt': 2,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000m42y',
#     'ids': ',us7000m42y,',
#     'sources': ',us,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,',
#     'nst': 41,
#     'dmin': 0.568,
#     'rms': 0.51,
#     'gap': 141,
#     'magType': 'mwr',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 75 km N of La Serena, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.3039, -29.2216, 45.334]},
#    'id': 'us7000m42y'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '167 km SE of Port Blair, India',
#     'time': 1709883452788,
#     'updated': 1709884400040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m42z',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m42z.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000m42z',
#     'ids': ',us7000m42z,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 6.137,
#     'rms': 0.69,
#     'gap': 64,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 167 km SE of Port Blair, India'},
#    'geometry': {'type': 'Point', 'coordinates': [93.7567, 10.5246, 161.535]},
#    'id': 'us7000m42z'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '36 km NNW of Upahuacho, Peru',
#     'time': 1709880894935,
#     'updated': 1709881903040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m42x',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m42x.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '7000m42x',
#     'ids': ',us7000m42x,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 56,
#     'dmin': 4.11,
#     'rms': 0.56,
#     'gap': 124,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 36 km NNW of Upahuacho, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-73.5907, -14.6257, 76.126]},
#    'id': 'us7000m42x'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '75 km S of Champerico, Guatemala',
#     'time': 1709877824734,
#     'updated': 1709880249040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m42p',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m42p.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000m42p',
#     'ids': ',us7000m42p,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 61,
#     'dmin': 1.694,
#     'rms': 0.94,
#     'gap': 186,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 75 km S of Champerico, Guatemala'},
#    'geometry': {'type': 'Point', 'coordinates': [-91.9711, 13.6166, 28.333]},
#    'id': 'us7000m42p'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '11 km NNW of Ashkāsham, Afghanistan',
#     'time': 1709877034679,
#     'updated': 1709879122040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m42n',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m42n.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000m42n',
#     'ids': ',us7000m42n,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': 2.695,
#     'rms': 0.38,
#     'gap': 103,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 11 km NNW of Ashkāsham, Afghanistan'},
#    'geometry': {'type': 'Point', 'coordinates': [71.5036, 36.7878, 261.02]},
#    'id': 'us7000m42n'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '76 km WNW of Ollagüe, Chile',
#     'time': 1709875503107,
#     'updated': 1709876166040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m42m',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m42m.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000m42m',
#     'ids': ',us7000m42m,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.549,
#     'rms': 0.79,
#     'gap': 60,
#     'magType': 'mb',
#     'type': 'earthquake',
# ...
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.8428333, 32.7791667, 4.92]},
#    'id': 'ci40680296'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '37 km NNW of Toyah, Texas',
#     'time': 1709457452817,
#     'updated': 1709459422716,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024ejzq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024ejzq.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'tx',
#     'code': '2024ejzq',
#     'ids': ',tx2024ejzq,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0,
#     'rms': 0.3,
#     'gap': 44,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 37 km NNW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-103.982, 31.607, 5.7455]},
#    'id': 'tx2024ejzq'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '35 km NNW of Toyah, Texas',
#     'time': 1709457398300,
#     'updated': 1709924656040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024ejzp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024ejzp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'tx',
#     'code': '2024ejzp',
#     'ids': ',us6000mgyq,tx2024ejzp,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 60,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 35 km NNW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-103.997, 31.583, 6.6125]},
#    'id': 'tx2024ejzp'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '36 km NNW of Toyah, Texas',
#     'time': 1709457353133,
#     'updated': 1709925158333,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024ejzn',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024ejzn.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.535,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 188,
#     'net': 'tx',
#     'code': '2024ejzn',
#     'ids': ',us6000mgg6,tx2024ejzn,',
#     'sources': ',us,tx,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': 18,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 49,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 36 km NNW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-103.978, 31.607, 6.51]},
#    'id': 'tx2024ejzn'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.9,
#     'place': '37 km NNW of Toyah, Texas',
#     'time': 1709457323955,
#     'updated': 1709925391355,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2024ejzm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2024ejzm.geojson',
#     'felt': 6,
#     'cdi': 5.7,
#     'mmi': 4.466,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 237,
#     'net': 'tx',
#     'code': '2024ejzm',
#     'ids': ',us6000mgfu,tx2024ejzm,',
#     'sources': ',us,tx,',
#     'types': ',dyfi,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 28,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.9 - 37 km NNW of Toyah, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-103.99, 31.611, 8.4454]},
#    'id': 'tx2024ejzm'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '61 km ENE of Yokohama, Japan',
#     'time': 1709454720042,
#     'updated': 1709472554271,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgfj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgfj.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 370,
#     'net': 'us',
#     'code': '6000mgfj',
#     'ids': ',us6000mgfj,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 59,
#     'dmin': 0.799,
#     'rms': 0.66,
#     'gap': 135,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 61 km ENE of Yokohama, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [141.9684, 41.2026, 60.365]},
#    'id': 'us6000mgfj'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '67 km NNW of Tanana, Alaska',
#     'time': 1709449944458,
#     'updated': 1709451577040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0242wb3itp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0242wb3itp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'ak',
#     'code': '0242wb3itp',
#     'ids': ',us6000mgf7,ak0242wb3itp,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.56,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 67 km NNW of Tanana, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.4363, 65.7569, 14.7]},
#    'id': 'ak0242wb3itp'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '19 km SSE of Murghob, Tajikistan',
#     'time': 1709449537835,
#     'updated': 1709450816040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgf6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgf6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000mgf6',
#     'ids': ',us6000mgf6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 38,
#     'dmin': 2.296,
#     'rms': 0.53,
#     'gap': 151,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 19 km SSE of Murghob, Tajikistan'},
#    'geometry': {'type': 'Point', 'coordinates': [74.0663, 38.0163, 152.579]},
#    'id': 'us6000mgf6'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.86,
#     'place': '10 km WSW of Petrolia, CA',
#     'time': 1709446852570,
#     'updated': 1709740343040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc74010961',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc74010961.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 126,
#     'net': 'nc',
#     'code': '74010961',
#     'ids': ',nc74010961,us6000mgez,',
#     'sources': ',nc,us,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 37,
#     'dmin': 0.05078,
#     'rms': 0.18,
#     'gap': 240,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 10 km WSW of Petrolia, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-124.406, 40.3035, 32.29]},
#    'id': 'nc74010961'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '36 km S of Coquimbo, Chile',
#     'time': 1709445931924,
#     'updated': 1709744088040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgew',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgew.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'us',
#     'code': '6000mgew',
#     'ids': ',us6000mgew,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 24,
#     'dmin': 0.376,
#     'rms': 0.35,
#     'gap': 173,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 36 km S of Coquimbo, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.3557, -30.2816, 43.502]},
#    'id': 'us6000mgew'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': 'western Indian-Antarctic Ridge',
#     'time': 1709444479117,
#     'updated': 1709835029040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m3xw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m3xw.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000m3xw',
#     'ids': ',us7000m3xw,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 16.642,
#     'rms': 0.52,
#     'gap': 117,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - western Indian-Antarctic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [123.6893, -48.8676, 10]},
#    'id': 'us7000m3xw'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': 'Owen Fracture Zone region',
#     'time': 1709444137150,
#     'updated': 1709837396040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mget',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mget.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '6000mget',
#     'ids': ',us6000mget,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 88,
#     'dmin': 13.343,
#     'rms': 0.91,
#     'gap': 97,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - Owen Fracture Zone region'},
#    'geometry': {'type': 'Point', 'coordinates': [57.7992, 11.6167, 10]},
#    'id': 'us6000mget'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.58,
#     'place': '60 km SE of Punta Cana, Dominican Republic',
#     'time': 1709441470330,
#     'updated': 1709443195578,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2024063000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2024063000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 197,
#     'net': 'pr',
#     'code': '2024063000',
#     'ids': ',pr2024063000,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.4855,
#     'rms': 0.29,
#     'gap': 200,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.6 - 60 km SE of Punta Cana, Dominican Republic'},
#    'geometry': {'type': 'Point', 'coordinates': [-68.0831, 18.1308, 101]},
#    'id': 'pr2024063000'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '178 km ENE of Agats, Indonesia',
#     'time': 1709440483747,
#     'updated': 1709442097040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mgel',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mgel.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '6000mgel',
#     'ids': ',us6000mgel,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 19,
#     'dmin': 2.514,
#     'rms': 0.86,
#     'gap': 125,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 178 km ENE of Agats, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [139.5475, -4.7634, 34.593]},
#    'id': 'us6000mgel'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': 'western Indian-Antarctic Ridge',
#     'time': 1709440338331,
#     'updated': 1709936487040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m3yr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m3yr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000m3yr',
#     'ids': ',us7000m3yr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 21,
#     'dmin': 16.641,
#     'rms': 1.1,
#     'gap': 84,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - western Indian-Antarctic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [123.745, -48.8536, 10]},
#    'id': 'us7000m3yr'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.53,
#     'place': '6 km SSW of Indios, Puerto Rico',
#     'time': 1709439609100,
#     'updated': 1709440021970,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71441793',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71441793.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'pr',
#     'code': '71441793',
#     'ids': ',pr71441793,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.04858,
#     'rms': 0.07,
#     'gap': 214,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 6 km SSW of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.842, 17.9416666666667, 15.14]},
#    'id': 'pr71441793'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.63,
#     'place': '6 km W of Borrego Springs, CA',
#     'time': 1709439110460,
#     'updated': 1709677852040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40680280',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40680280.geojson',
#     'felt': 25,
#     'cdi': 3.8,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'ci',
#     'code': '40680280',
#     'ids': ',ci40680280,us6000mged,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 98,
#     'dmin': 0.01454,
#     'rms': 0.18,
#     'gap': 15,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 6 km W of Borrego Springs, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.4338333, 33.2641667, 4.88]},
#    'id': 'ci40680280'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '272 km NW of Houma, Tonga',
#     'time': 1709436371777,
#     'updated': 1709866402040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m3xr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m3xr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000m3xr',
#     'ids': ',us7000m3xr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 29,
#     'dmin': 2.527,
#     'rms': 0.72,
#     'gap': 66,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 272 km NW of Houma, Tonga'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-177.4492, -19.7655, 528.244]},
#    'id': 'us7000m3xr'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '4 km ENE of Guaymango, El Salvador',
#     'time': 1709436029429,
#     'updated': 1709437684040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mge6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000mge6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '6000mge6',
#     'ids': ',us6000mge6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': 0.136,
#     'rms': 1.04,
#     'gap': 203,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 4 km ENE of Guaymango, El Salvador'},
#    'geometry': {'type': 'Point', 'coordinates': [-89.8088, 13.7683, 95.256]},
#    'id': 'us6000mge6'}],
#  'bbox': [-179.6697, -59.35, 0, 179.8302, 67.3537, 602.492]}

# %% [markdown]
# Since JSON is just a dictionary, we can access subsets of the data can with square brackets, using labels for the named elements in a key-value pair, and numerals for positional indexing of list items.
#
# Hint: whenever you see a file that ends in `.geojson`, you'll probably want to extract the data thats stored in the `features` dictionary:

# %%
quakes = data['features']
quakes[0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 2.49,
#   'place': '3 km S of Magas Arriba, Puerto Rico',
#   'time': 1710036846200,
#   'updated': 1710037574360,
#   'tz': None,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71442638',
#   'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442638.geojson',
#   'felt': None,
#   'cdi': None,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 95,
#   'net': 'pr',
#   'code': '71442638',
#   'ids': ',pr71442638,',
#   'sources': ',pr,',
#   'types': ',origin,phase-data,',
#   'nst': 15,
#   'dmin': 0.04526,
#   'rms': 0.12,
#   'gap': 153,
#   'magType': 'md',
#   'type': 'earthquake',
#   'title': 'M 2.5 - 3 km S of Magas Arriba, Puerto Rico'},
#  'geometry': {'type': 'Point',
#   'coordinates': [-66.7626666666667, 17.9838333333333, 12.72]},
#  'id': 'pr71442638'}

# %% [markdown]
# Because it is a nested dictionary at this point, we can use indexing into the dictionary to extract results.  Recall our earlier use of nested dictionaries? This is why we learned how to navigate nested dictionaries:

# %%
for q in quakes:
    print(q['properties']['title'])
# Out:
# M 2.5 - 3 km S of Magas Arriba, Puerto Rico
# M 3.5 - 7 km WSW of Petrolia, CA
# M 2.5 - 55 km NE of Kobuk, Alaska
# M 4.3 - south of the Fiji Islands
# M 4.9 - 16 km E of Calama, Chile
# M 5.0 - 128 km W of Valparaíso, Chile
# M 3.6 - 127 km N of Hatillo, Puerto Rico
# M 4.4 - 41 km ENE of La Tirana, Chile
# M 2.5 - 9 km E of Pāhala, Hawaii
# M 2.6 - 3 km SSW of Indios, Puerto Rico
# M 2.8 - 5 km E of Elgin, South Carolina
# M 2.5 - 18 km NNE of Stanley, Idaho
# M 2.7 - 273 km SSE of Akhiok, Alaska
# M 4.3 - 115 km WNW of Aykol, China
# M 5.5 - 238 km E of Levuka, Fiji
# M 3.1 - 48 km NW of San Antonio, Puerto Rico
# M 4.5 - 134 km SW of San Pedro de Atacama, Chile
# M 4.4 - 47 km SSW of Ollagüe, Chile
# M 2.7 - 3 km S of Independence, CA
# M 3.4 - 37 km NNW of San Antonio, Puerto Rico
# M 2.5 - 66 km ENE of Cordova, Alaska
# M 3.2 - 11 km NNW of Virginia City, Nevada
# M 4.9 - 42 km S of Shizunai-furukawachō, Japan
# M 4.3 - 84 km ENE of Nagqu, China
# M 2.5 - 10 km NE of Hawaiian Ocean View, Hawaii
# M 2.8 - 17 km E of Willows, CA
# M 2.9 - 20 km NNE of Stanley, Idaho
# M 2.5 - 8 km ENE of Verden, Oklahoma
# M 2.7 - 5 km WSW of Guánica, Puerto Rico
# M 2.5 - 60 km S of Whites City, New Mexico
# M 2.5 - 6 km S of Pāhala, Hawaii
# M 2.9 - 54 km NW of Toyah, Texas
# M 3.0 - 18 km WSW of La Jolla, CA
# M 3.8 - 32 km ENE of Cruz Bay, U.S. Virgin Islands
# M 3.0 - 40 km NNW of San Antonio, Puerto Rico
# M 2.5 - 8 km SSE of Guánica, Puerto Rico
# M 4.3 - 5 km SW of Ichinomiya, Japan
# M 4.6 - 81 km SSE of Hengchun, Taiwan
# M 2.5 - 11 km S of Guánica, Puerto Rico
# M 3.5 - 47 km NNE of Cruz Bay, U.S. Virgin Islands
# M 4.0 - 15 km WNW of Rancagua, Chile
# M 5.3 - south of the Fiji Islands
# M 2.5 - 9 km NNW of Stanley, Idaho
# M 3.6 - 91 km N of Culebra, Puerto Rico
# M 2.9 - 10 km ESE of Chickasha, Oklahoma
# M 3.5 - 11 km S of Bullaburra, Australia
# M 6.0 - 98 km SE of Pondaguitan, Philippines
# M 3.0 - 16 km S of Atoka, New Mexico
# M 4.6 - 75 km N of La Serena, Chile
# M 4.4 - 167 km SE of Port Blair, India
# M 4.8 - 36 km NNW of Upahuacho, Peru
# M 4.3 - 75 km S of Champerico, Guatemala
# M 4.1 - 11 km NNW of Ashkāsham, Afghanistan
# M 4.3 - 76 km WNW of Ollagüe, Chile
# M 4.7 - 16 km E of Ródos, Greece
# M 2.6 - 72 km W of Petersville, Alaska
# M 2.6 - 85 km SE of Ugashik, Alaska
# M 5.0 - 90 km NE of Sanana, Indonesia
# M 2.7 - 107 km W of Petrolia, CA
# M 2.6 - 11 km SSE of Maria Antonia, Puerto Rico
# M 2.6 - 7 km NNW of Smiths Ferry, Idaho
# M 3.0 - 3 km WSW of La Parguera, Puerto Rico
# M 2.6 - 6 km NNW of Smiths Ferry, Idaho
# M 4.5 - south of the Fiji Islands
# M 2.7 - 11 km NNW of Virginia City, Nevada
# M 4.3 - 81 km ESE of La Tirana, Chile
# M 4.5 - Banda Sea
# M 4.8 - Kuril Islands
# M 2.9 - 81 km W of Anvik, Alaska
# M 4.2 - 70 km W of Illapel, Chile
# M 2.9 - 54 km NNE of Kobuk, Alaska
# M 2.9 - 19 km NNE of Stanley, Idaho
# M 2.9 - 57 km S of Whites City, New Mexico
# M 4.3 - 41 km ENE of Noda, Japan
# M 4.5 - 220 km SSW of Tambolaka, Indonesia
# M 2.9 - 17 km S of Central Aguirre, Puerto Rico
# M 2.5 - 8 km NW of Smiths Ferry, Idaho
# M 4.8 - southeast of Easter Island
# M 2.9 - 4 km E of Jayuya, Puerto Rico
# M 4.6 - 61 km SSW of La Tirana, Chile
# M 3.3 - 29 km NNE of Suárez, Puerto Rico
# M 5.0 - 9 km SSE of Chincha Alta, Peru
# M 4.6 - 37 km SSW of Pathein, Myanmar
# M 4.4 - 37 km ENE of Kuji, Japan
# M 4.4 - 111 km S of Yudomari, Japan
# M 4.5 - 6 km W of Surup, Philippines
# M 5.0 - 228 km NNE of Nagqu, China
# M 5.6 - 246 km NNE of Nagqu, China
# M 4.7 - 67 km SSW of Labuha, Indonesia
# M 5.7 - 78 km SW of Tamarindo, Costa Rica
# M 4.4 - 22 km SSW of Saiki, Japan
# M 4.3 - 25 km ENE of Anamizu, Japan
# M 3.3 - 92 km N of Tierras Nuevas Poniente, Puerto Rico
# M 2.6 - 27 km NNE of Queets, Washington
# M 4.2 - 267 km N of Kuril’sk, Russia
# M 2.6 - 35 km WSW of Petersville, Alaska
# M 4.3 - 53 km SW of Ollagüe, Chile
# M 4.7 - 71 km ESE of Sarangani, Philippines
# M 2.6 - 14 km ENE of Boulder City, Nevada
# M 3.1 - 7 km WSW of Snoqualmie, Washington
# M 2.8 - 39 km WNW of Cantwell, Alaska
# M 2.7 - 16 km NNW of Anderson, Alaska
# M 3.6 - 56 km ESE of Punta Cana, Dominican Republic
# M 2.9 - 1 km SW of Dubrava, Croatia
# M 5.1 - 174 km ENE of Tual, Indonesia
# M 3.2 - 57 km W of Puerto Real, Puerto Rico
# M 5.1 - 62 km ENE of Kinablangan, Philippines
# M 5.1 - 42 km ENE of Kinablangan, Philippines
# M 4.8 - 11 km SSE of Marihatag, Philippines
# M 5.0 - 26 km WSW of Lata, Solomon Islands
# M 2.8 - 18 km E of Pleasanton, Texas
# M 4.5 - 73 km NE of Kashgar, China
# M 5.1 - 133 km NNE of Hihifo, Tonga
# M 4.4 - 64 km ESE of Marihatag, Philippines
# M 2.5 - 2 km NNE of Nanwalek, Alaska
# M 2.6 - 17 km WNW of Seldovia, Alaska
# M 4.8 - 128 km S of False Pass, Alaska
# M 2.5 - 26 km SSE of Campo, CA
# M 4.4 - 53 km W of Ollagüe, Chile
# M 4.3 - Fiji region
# M 4.1 - 50 km NNE of Chickaloon, Alaska
# M 4.5 - 259 km WSW of Tofino, Canada
# M 2.6 - 27 km S of Denali National Park, Alaska
# M 2.8 - 54 km NNE of Kobuk, Alaska
# M 2.9 - 10 km WSW of Petrolia, CA
# M 4.3 - Fiji region
# M 4.3 - 61 km NW of Burang, China
# M 4.4 - 99 km WSW of San Antonio de los Cobres, Argentina
# M 4.8 - 235 km WNW of Houma, Tonga
# M 3.6 - 118 km N of Suárez, Puerto Rico
# M 3.2 - 11 km NNW of Virginia City, Nevada
# M 5.1 - 127 km WNW of Aykol, China
# M 2.7 - 13 km ESE of Olney, Texas
# M 2.7 - 23 km ENE of Ouzinkie, Alaska
# M 2.6 - 48 km W of Mentone, Texas
# M 4.4 - Kepulauan Babar, Indonesia
# M 2.7 - 10 km ENE of Pāhala, Hawaii
# M 3.4 - 3 km WSW of Sabana Grande, Puerto Rico
# M 5.1 - south of the Fiji Islands
# M 4.3 - 37 km SW of Tocopilla, Chile
# M 2.6 - 7 km SSE of Maria Antonia, Puerto Rico
# M 6.1 - Macquarie Island region
# M 2.5 - 104 km ESE of Akutan, Alaska
# M 4.5 - Fiji region
# M 2.5 - 6 km ENE of Pinckneyville, Illinois
# M 2.6 - 21 km NNE of Old Harbor, Alaska
# M 4.0 - 48 km NW of San Antonio, Puerto Rico
# M 3.8 - 60 km SE of Punta Cana, Dominican Republic
# M 4.3 - 33 km SE of Karpathos, Greece
# M 3.4 - 9 km N of Smiths Ferry, Idaho
# M 3.2 - 158 km ESE of Chignik, Alaska
# M 5.3 - 62 km ESE of Pangai, Tonga
# M 4.8 - Reykjanes Ridge
# M 2.8 - 7 km ESE of La Parguera, Puerto Rico
# M 3.3 - 48 km NW of San Antonio, Puerto Rico
# M 3.8 - 37 km SSW of Los Ybanez, Texas
# M 2.5 - 2 km ENE of Magas Arriba, Puerto Rico
# M 4.5 - 48 km NNE of Kon Tum, Vietnam
# M 4.1 - 231 km WSW of Tual, Indonesia
# M 4.0 - 49 km NW of San Antonio, Puerto Rico
# M 3.7 - 25 km ESE of Punta Cana, Dominican Republic
# M 4.3 - 113 km ESE of Caburan, Philippines
# M 5.1 - 62 km NNW of Fannūj, Iran
# M 2.7 - 2 km ENE of Magas Arriba, Puerto Rico
# M 4.2 - 8 km N of San Pedro de Atacama, Chile
# M 3.1 - 6 km W of Maricao, Puerto Rico
# M 3.1 - 44 km NW of San Antonio, Puerto Rico
# M 5.4 - 243 km NNE of Nagqu, China
# M 4.3 - 100 km N of Tobelo, Indonesia
# M 3.4 - 49 km NW of San Antonio, Puerto Rico
# M 3.2 - 49 km NW of San Antonio, Puerto Rico
# M 4.4 - 107 km SW of Pelabuhanratu, Indonesia
# M 2.5 - 25 km E of Knik River, Alaska
# M 2.8 - 5 km SSW of Houston, Alaska
# M 2.5 - 53 km S of Whites City, New Mexico
# M 3.3 - 54 km S of Whites City, New Mexico
# M 2.9 - 44 km NW of San Antonio, Puerto Rico
# M 4.9 - 12 km N of Camiña, Chile
# M 3.3 - 50 km NW of San Antonio, Puerto Rico
# M 3.8 - 47 km NW of San Antonio, Puerto Rico
# M 4.6 - 2 km WSW of Culaman, Philippines
# M 3.8 - 17 km E of Crescent Valley, Nevada
# M 2.6 - 55 km S of Whites City, New Mexico
# M 2.5 - 55 km S of Whites City, New Mexico
# M 4.2 - 21 km WNW of Itháki, Greece
# M 4.4 - 116 km ESE of Tomioka, Japan
# M 4.3 - 21 km NE of Hamdibey, Turkey
# M 3.1 - 12 km N of Coyanosa, Texas
# M 4.6 - Fiji region
# M 4.4 - 4 km NW of Ricardo Palma, Peru
# M 4.7 - 44 km SSE of Malim, Philippines
# M 2.6 - 10 km SSE of Maria Antonia, Puerto Rico
# M 2.9 - 8 km NNW of Smiths Ferry, Idaho
# M 4.5 - Kermadec Islands region
# M 3.5 - 24 km W of Pole Ojea, Puerto Rico
# M 2.8 - 2 km NNE of Magas Arriba, Puerto Rico
# M 4.5 - 72 km W of Ollagüe, Chile
# M 4.6 - 43 km W of Coquimbo, Chile
# M 2.5 - 34 km SE of Mina, Nevada
# M 4.5 - 130 km WNW of Aykol, China
# M 2.6 - 40 km NNW of Toyah, Texas
# M 4.9 - 107 km SSW of Pagar Alam, Indonesia
# M 3.7 - 142 km S of Kyzyl-Suu, Kyrgyzstan
# M 5.3 - 29 km NNW of Cholpon-Ata, Kyrgyzstan
# M 3.5 - 55 km N of Cruz Bay, U.S. Virgin Islands
# M 3.9 - 24 km SSE of Atka, Alaska
# M 3.9 - 29 km SE of King Cove, Alaska
# M 4.9 - South Sandwich Islands region
# M 3.5 - 0 km E of Magas Arriba, Puerto Rico
# M 4.0 - 40 km S of La Libertad, El Salvador
# M 4.3 - 84 km NE of Aksu, China
# M 4.2 - 9 km S of San Marcos, Mexico
# M 5.2 - 225 km S of Bengkulu, Indonesia
# M 2.7 - 23 km SE of Elmo, Utah
# M 3.3 - 86 km NE of Dawson City, Canada
# M 3.5 - 63 km NNE of Cold Bay, Alaska
# M 4.0 - 63 km ESE of La Tirana, Chile
# M 2.7 - 27 km SSW of Ocotillo Wells, CA
# M 2.5 - 38 km NNW of Toyah, Texas
# M 2.9 - 68 km NNE of Luquillo, Puerto Rico
# M 4.1 - 72 km SE of Inarajan Village, Guam
# M 4.5 - 15 km SE of Marihatag, Philippines
# M 4.4 - 275 km ENE of Nabire, Indonesia
# M 5.0 - Southwest Indian Ridge
# M 4.2 - 55 km SW of Puerto San José, Guatemala
# M 2.6 - 33 km SE of King Salmon, Alaska
# M 6.7 - Macquarie Island region
# M 5.0 - Easter Island region
# M 5.1 - 117 km SSW of Pagar Alam, Indonesia
# M 2.5 - 8 km WNW of Beluga, Alaska
# M 4.2 - 14 km NNW of Gölbaşı, Turkey
# M 4.5 - 25 km ENE of Parapat, Indonesia
# M 2.5 - 37 km WSW of Mentone, Texas
# M 4.1 - 252 km WNW of Houma, Tonga
# M 4.4 - 188 km ENE of Lospalos, Timor Leste
# M 3.0 - 1 km W of Pāhala, Hawaii
# M 4.2 - 130 km ENE of Tual, Indonesia
# M 3.9 - 137 km NNE of Vieques, Puerto Rico
# M 3.3 - 37 km WSW of Mentone, Texas
# M 4.6 - southwestern Atlantic Ocean
# M 4.4 - 133 km W of Aykol, China
# M 3.2 - 38 km NNW of Toyah, Texas
# M 2.5 - 15 km ENE of Ocotillo, CA
# M 2.7 - 37 km NNW of Toyah, Texas
# M 2.9 - 35 km NNW of Toyah, Texas
# M 3.5 - 36 km NNW of Toyah, Texas
# M 3.9 - 37 km NNW of Toyah, Texas
# M 4.9 - 61 km ENE of Yokohama, Japan
# M 3.2 - 67 km NNW of Tanana, Alaska
# M 4.3 - 19 km SSE of Murghob, Tajikistan
# M 2.9 - 10 km WSW of Petrolia, CA
# M 4.0 - 36 km S of Coquimbo, Chile
# M 4.6 - western Indian-Antarctic Ridge
# M 4.9 - Owen Fracture Zone region
# M 3.6 - 60 km SE of Punta Cana, Dominican Republic
# M 4.9 - 178 km ENE of Agats, Indonesia
# M 4.7 - western Indian-Antarctic Ridge
# M 2.5 - 6 km SSW of Indios, Puerto Rico
# M 2.6 - 6 km W of Borrego Springs, CA
# M 4.2 - 272 km NW of Houma, Tonga
# M 4.3 - 4 km ENE of Guaymango, El Salvador

# %% [markdown]
# **SIDE BAR: GeoJSON?**
#
# Working with geospatial data over the web, you will inevitably encounter called GeoJSON. GeoJSON is just JSON (which is just...???) with a slightly more well-defined schema to distinguish between metadata, spatial features, and classes of spatial features (e.g. points vs. lines vs. polygons).
#
# There's lots of great tools out there for working with GeoJSON, but chief among them is [geojson.io](https://geojson.io). Try copying the first 5 entries from the quakes list into the `features` list on geojson.io and see what you find.
#
# HINT: it's a little bit tricker to go from Python to JSON than from JSON to Python because Python doesn't care about single-quotes vs. double quotes, but JavaScript does. You can use the `json.dumps()` method to convert a Python dictionary to a valid JSON string.

# %%
print(json.dumps(response.json()['features'][:5]))
# Out:
# [{"type": "Feature", "properties": {"mag": 2.49, "place": "3 km S of Magas Arriba, Puerto Rico", "time": 1710036846200, "updated": 1710037574360, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/pr71442638", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71442638.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 95, "net": "pr", "code": "71442638", "ids": ",pr71442638,", "sources": ",pr,", "types": ",origin,phase-data,", "nst": 15, "dmin": 0.04526, "rms": 0.12, "gap": 153, "magType": "md", "type": "earthquake", "title": "M 2.5 - 3 km S of Magas Arriba, Puerto Rico"}, "geometry": {"type": "Point", "coordinates": [-66.7626666666667, 17.9838333333333, 12.72]}, "id": "pr71442638"}, {"type": "Feature", "properties": {"mag": 3.46, "place": "7 km WSW of Petrolia, CA", "time": 1710032405510, "updated": 1710036784349, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc74014796", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc74014796.geojson", "felt": 1, "cdi": 2, "mmi": 1.932, "alert": null, "status": "automatic", "tsunami": 0, "sig": 184, "net": "nc", "code": "74014796", "ids": ",nc74014796,us7000m4gr,", "sources": ",nc,us,", "types": ",dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,shakemap,", "nst": 23, "dmin": 0.02808, "rms": 0.15, "gap": 235, "magType": "ml", "type": "earthquake", "title": "M 3.5 - 7 km WSW of Petrolia, CA"}, "geometry": {"type": "Point", "coordinates": [-124.3691635, 40.3078346, 29.74]}, "id": "nc74014796"}, {"type": "Feature", "properties": {"mag": 2.5, "place": "55 km NE of Kobuk, Alaska", "time": 1710031596753, "updated": 1710031811381, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ak02437rw8bm", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak02437rw8bm.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "automatic", "tsunami": 0, "sig": 96, "net": "ak", "code": "02437rw8bm", "ids": ",ak02437rw8bm,", "sources": ",ak,", "types": ",origin,phase-data,", "nst": null, "dmin": null, "rms": 0.8, "gap": null, "magType": "ml", "type": "earthquake", "title": "M 2.5 - 55 km NE of Kobuk, Alaska"}, "geometry": {"type": "Point", "coordinates": [-155.8861, 67.2212, 30]}, "id": "ak02437rw8bm"}, {"type": "Feature", "properties": {"mag": 4.3, "place": "south of the Fiji Islands", "time": 1710016648002, "updated": 1710025806040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4g5", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4g5.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 284, "net": "us", "code": "7000m4g5", "ids": ",us7000m4g5,", "sources": ",us,", "types": ",origin,phase-data,", "nst": 39, "dmin": 5.231, "rms": 0.63, "gap": 99, "magType": "mb", "type": "earthquake", "title": "M 4.3 - south of the Fiji Islands"}, "geometry": {"type": "Point", "coordinates": [179.8302, -24.4128, 523.847]}, "id": "us7000m4g5"}, {"type": "Feature", "properties": {"mag": 4.9, "place": "16 km E of Calama, Chile", "time": 1710014333172, "updated": 1710028511040, "tz": null, "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000m4fz", "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000m4fz.geojson", "felt": null, "cdi": null, "mmi": null, "alert": null, "status": "reviewed", "tsunami": 0, "sig": 369, "net": "us", "code": "7000m4fz", "ids": ",us7000m4fz,", "sources": ",us,", "types": ",origin,phase-data,", "nst": 27, "dmin": 0.743, "rms": 0.58, "gap": 66, "magType": "mb", "type": "earthquake", "title": "M 4.9 - 16 km E of Calama, Chile"}, "geometry": {"type": "Point", "coordinates": [-68.7627, -22.4382, 128.192]}, "id": "us7000m4fz"}]

# %% [markdown]
# Extracting data from nested dictionaries might be a good job for **list comprehension**:

# %%
d = {
    'magnitude': [q['properties']['mag'] for q in quakes],
    'depth': [q['geometry']['coordinates'][2] for q in quakes]
}
df = pd.DataFrame.from_dict(d)

df.head()
# Out:
#    magnitude    depth
# 0       2.49   12.720
# 1       3.46   29.740
# 2       2.50   30.000
# 3       4.30  523.847
# 4       4.90  128.192

# %%
print(df.describe())
# Out:
#         magnitude       depth
# count  261.000000  261.000000
# mean     3.753333   61.329340
# std      0.942589  115.104787
# min      2.450000    0.000000
# 25%      2.800000    9.800000
# 50%      3.820000   15.000000
# 75%      4.500000   61.571000
# max      6.700000  602.492000

# %%
df.plot(x='magnitude', y='depth', kind='scatter')
# Out:
# <Axes: xlabel='magnitude', ylabel='depth'>

# %% [markdown]
# # 3. Geocoding
#
# Now on to the main course: geocoding APIs.

# %% [markdown]
# ## 3.1. What is geocoding?

# %% [markdown]
# **Geocoding** describes the process of converting place names and addresses to geographic coordinates (e.g. lat/lon).

# %% [markdown]
# <center><img src="https://dmpublisher.s3-us-west-2.amazonaws.com/old-dm/directionsmag.com/ee/images/newsletter/2004/10_20/EDramowicz_Figure1_lg.gif"></center>

# %% [markdown]
# Reverse geocoding is just the opposite process: using geographic coordinates to extract meaningful place names/addresses.

# %% [markdown]
# Perhaps this sounds like a dull topic, but **geocoding is a fundamental tool for anyone wishing to do spatial data analysis**.
#
# Why?

# %% [markdown]
# - 9 times out of 10, your data will have _either_ geographic coordinates _or_ administrative boundary names, but not both!
# - 9 times out of 10 you will want to use additional data sources for which the above statement also applies
# - Geocoding allows you to translate between the two (e.g. merging Census data into Craiglist rental listings)

# %% [markdown]
# ## 3.2 Geocoding with the Mapbox API

# %% [markdown]
# Services like Google Maps and Mapbox have various APIs that let you access its services through code instead of through GUI apps. This one from Mapbox lets you look up the latitude-longitude coordinates of street addresses. You'll need to create a Mapbox API token in order to use this API, which you can do by following the instructions [here ](https://www.mapbox.com/signin/?route-to=%22/account/access-tokens%22) if you have not alread done so.

# %% [markdown]
# The Mapbox API queries work just like the ones we've already seen, but now we're including our own query parameters in the URL endpoint!
#
# **API documentation:**
# https://www.mapbox.com/api-documentation/#geocoding
#
# **API endpoint:**
# https://api.mapbox.com/geocoding/v5/mapbox.places
#
# **API endpoint with query parameters:**
# https://api.mapbox.com/geocoding/v5/mapbox.places/Wurster+Hall.json?access_token=pk.eyJ1IjoiY3AyNTVkZW1vIiwiYSI6ImRPcTlnTUEifQ.3C0d0Nk_rcwV-8JF29PU-w

# %% [markdown]
# ### 3.2.1. A word about API keys, tokens, and passwords in general
#
# It's never a good idea to print an API key in a public document, including a script or notebook like this one. Particularly when you're using Git, deleting private data after you've already committed the change won't remove the data from your project history!
#
# Instead, its good practice to create a small .json file which you can read into Python without ever having to print its contents. In this case, let's use a text editor to create a file named **mapbox_api_key.json** and put it in the `data/` directory. It's contents should look like this:
#
# ```javascript
# {"key":"pk.eyJ1IjoidGFibGVkdWRlIiwiYSI6ImNsaGpmYmNhNjBoYTMzZm10aXl3OGtuZGcifQ.Rzi4EhaiUCLWCqCUq-CpCQ"}
# ```
#
# Now we can read the API key from disk:

# %%
import json

with open("data/mapbox_api_key.json", 'r') as f:
    key_file = f.read()
    
my_api_key = json.loads(key_file)['key']

# %% [markdown]
# ### 3.2.2. Constructing an API query
# Now we're ready to format our API request.

# %%
import requests

base_url = 'https://api.mapbox.com/geocoding/v5/mapbox.places/'
address = 'Goldman School of Public Policy'
params = {
    'limit': 1,  # just get the first record
    'access_token': my_api_key}

url = requests.Request('GET', base_url + address + '.json', params=params).prepare().url

# %% [markdown]
# This looks a little more complicated than what we saw last class. The main reason for this is that we are now doing more than simply submitting a `GET` request to URL whose full endpoint we know in advance. Instead, we just know the base URL of our API, and are using strings and key-value pairs to format the rest of the endpoint. This is pretty straightforward with one exception: HTTP doesn't know how to handle white space `" "` and many other special characters. So we are relying on the `Request.prepare()` method to take our input data and format it into a string that can be understood by HTTP.
#
# You can try printing the url in the cell below to see what this formatted version of the URL looks like, but be careful because it will contain your API key!

# %%
print(url)
# Out:
# https://api.mapbox.com/geocoding/v5/mapbox.places/Goldman%20School%20of%20Public%20Policy.json?limit=1&access_token=pk.eyJ1IjoidGFibGVkdWRlIiwiYSI6ImNsaGpmYmNhNjBoYTMzZm10aXl3OGtuZGcifQ.Rzi4EhaiUCLWCqCUq-CpCQ

# %% [markdown]
# ### 3.2.3. Making the request and parsing the response

# %%
from pprint import PrettyPrinter as pp
response = requests.get(url)
results = response.text
data = json.loads(results)
data
# Out:
# {'type': 'FeatureCollection',
#  'query': ['goldman', 'school', 'of', 'public', 'policy'],
#  'features': [{'id': 'poi.386547076057',
#    'type': 'Feature',
#    'place_type': ['poi'],
#    'relevance': 1,
#    'properties': {'foursquare': '4b82e670f964a520f5eb30e3',
#     'landmark': True,
#     'wikidata': 'Q5580240',
#     'address': '1893 Le Roy ave',
#     'category': 'college, university, building'},
#    'text': 'Goldman School of Public Policy',
#    'place_name': 'Goldman School of Public Policy, 1893 Le Roy ave, Berkeley, California 94720, United States',
#    'center': [-122.2579385, 37.8756075],
#    'geometry': {'coordinates': [-122.2579385, 37.8756075], 'type': 'Point'},
#    'context': [{'id': 'neighborhood.44674284',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBcW1zN0E',
#      'text': 'Berkeley Hills'},
#     {'id': 'postcode.314502892',
#      'mapbox_id': 'dXJuOm1ieHBsYzpFcjd1N0E',
#      'text': '94720'},
#     {'id': 'place.25790700',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#      'wikidata': 'Q484678',
#      'text': 'Berkeley'},
#     {'id': 'district.214764',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#      'wikidata': 'Q107146',
#      'text': 'Alameda County'},
#     {'id': 'region.419052',
#      'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#      'wikidata': 'Q99',
#      'short_code': 'US-CA',
#      'text': 'California'},
#     {'id': 'country.8940',
#      'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2024 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %% [markdown]
# Does anyone think they have what it takes to extract the coordinates from our API response data?

# %%
data['features'][0]['center']
# Out:
# [-122.2579385, 37.8756075]

# %% [markdown]
# ### 3.2.5 Exercises
#
# 1. Search for some other addresses or landmarks!
# 2. Try storing your code as a function named `get_coords()` so that you need only supply a place name and your function will return the coordinates as list or tuple:
#    ```python
#     def get_coords(place_str):
#
#         # do something with "place_str"
#
#         return coords
#
#    ```
# 2. Take a look at the [API documentation](https://www.mapbox.com/api-documentation/#geocoding). Can you figure out how to retrieve other points of interest near Wurster Hall?

# %%
def get_coords(place_str):
    # do something with "place_str"
    base_url = 'https://api.mapbox.com/geocoding/v5/mapbox.places/'
    address = place_str
    params = {'limit': 1,  # just get the first record
              'access_token': my_api_key}
    url = requests.Request('GET', base_url + address + '.json', params=params).prepare().url
    response = requests.get(url)
    results = response.text
    data = json.loads(results)
    cords = data['features'][0]['center']
    return cords

# %%
get_coords('Lick-Wilmerding')
# Out:
# [-122.4490105, 37.7222705]

# %% [markdown]
# ### 3.2.4. The Mapbox SDK

# %% [markdown]
# Mapbox also maintans its own Python package which makes it a little easier to execute HTTP requests against its API. You can find the documentation [here](https://mapbox-mapbox.readthedocs-hosted.com/en/latest/index.html)
#
# NOTE: the Mapbox Python API seems to be a bit buggy. In particular it doesn't seem to support Python > 3.9. If you encounter any issues trying to import modules from this library, the best thing to do is to roll back your Python version. From a terminal, you can do:
#
# ```bash
# conda install python=3.9
# ```
#
# and then restart your notebook kernel using the Kernel drop down menu in the menu panel above (or by typing `00` in rapid succession in command mode).

# %% [markdown]
# #### 3.2.4.1. Forward Geocoding
#
# Forward geocoding is the one we have looked at so far using an API endpoint.  It takes an address or a place name and returns the geographic coordinates of that location.  Let's look at it again using the Mapbox Python SDK.

# %%
from mapbox import Geocoder
import os

geocoder = Geocoder(access_token=my_api_key)

# %% [markdown]
# OK, now we can get to work on the geocoding... let's try geocoding Freehouse Restaurant, which is at 2700 Bancroft Way.

# %%
response = geocoder.forward('2700 Bancroft Way, Berkeley, CA 94704', limit=1)
data = response.json()
data
# Out:
# {'type': 'FeatureCollection',
#  'query': ['2700', 'bancroft', 'way', 'berkeley', 'ca', '94704'],
#  'features': [{'id': 'address.5245703210851352',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'rooftop',
#     'mapbox_id': 'dXJuOm1ieGFkcjozOTU5MmExNi0zMWIzLTRhNzgtOWM2YS1iYjU5OTI1OTgyOWY'},
#    'text': 'Bancroft Way',
#    'place_name': '2700 Bancroft Way, Berkeley, California 94704, United States',
#    'center': [-122.254353, 37.869075],
#    'geometry': {'type': 'Point', 'coordinates': [-122.254353, 37.869075]},
#    'address': '2700',
#    'context': [{'id': 'neighborhood.595160300',
#      'mapbox_id': 'dXJuOm1ieHBsYzpJM2xzN0E',
#      'text': 'South Campus'},
#     {'id': 'postcode.314437356',
#      'mapbox_id': 'dXJuOm1ieHBsYzpFcjN1N0E',
#      'text': '94704'},
#     {'id': 'place.25790700',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#      'wikidata': 'Q484678',
#      'text': 'Berkeley'},
#     {'id': 'district.214764',
#      'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#      'wikidata': 'Q107146',
#      'text': 'Alameda County'},
#     {'id': 'region.419052',
#      'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#      'wikidata': 'Q99',
#      'short_code': 'US-CA',
#      'text': 'California'},
#     {'id': 'country.8940',
#      'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2024 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %% [markdown]
# Another random address to geocode:

# %%
response = geocoder.forward('120 East 13th Street, Manhattan, New York, New York 10003', limit = 1)
first = response.json()['features'][0]
print(first['place_name'])
print([coord for coord in first['geometry']['coordinates']])
# Out:
# 120 East 13th Street, New York, New York 10003, United States
# [-73.988953, 40.73292]

# %% [markdown]
# #### 3.2.4.2 Creating a dataframe from multiple API queries
#
# Can you think of a good way to write a loop to geocode those addresses and add them to a dataframe?  Let's try one way to do this.

# %%
import pandas as pd
data = pd.DataFrame(index=[], columns=['address','lat','lon'])

addrs = [
    '3028 Regent St., Berkeley, California, 94705',
    '1511 Julia St, Berkeley, California, 94703',
    '2700 Bancroft, Berkeley, California, 94704']

# %%
for i in range(len(addrs)):
    geoadress=geocoder.forward(addrs[i], limit = 1).geojson()['features'][0]['geometry']['coordinates']
    data.loc[i, 'address']=addrs[i]
    data.loc[i, 'lon']=geoadress[0]
    data.loc[i, 'lat']=geoadress[1]
data
# Out:
#                                         address        lat         lon
# 0  3028 Regent St., Berkeley, California, 94705  37.854475 -122.256706
# 1    1511 Julia St, Berkeley, California, 94703  37.854482 -122.278695
# 2    2700 Bancroft, Berkeley, California, 94704  37.869075 -122.254353

# %% [markdown]
# #### 3.2.4.3 Reverse Geocoding
#
# Reverse geocoding does what it sounds like. It takes coordinates and returns an address or other place type.  Options for place type include: country, region, postcode, district, place, locality, neighborhood, address,and poi.
#
# Let's start by using the coordinates of the address we just got from forward geocoding, and get the address back from reverse geocoding of those coordinates.

# %%
response = geocoder.reverse(lat=37.868965, lon=-122.254267)
features = response.geojson()['features']
features
# Out:
# [{'id': 'address.795769205773300',
#   'type': 'Feature',
#   'place_type': ['address'],
#   'relevance': 1,
#   'properties': {'accuracy': 'parcel',
#    'mapbox_id': 'dXJuOm1ieGFkcjo2N2NmZGFlOC1kNTdmLTRiM2MtOGU0ZS0xMzVlMWZjNTE4ZTk'},
#   'text': 'College Avenue',
#   'place_name': '2315 College Avenue, Berkeley, California 94704, United States',
#   'center': [-122.2542525, 37.8689695],
#   'geometry': {'type': 'Point', 'coordinates': [-122.2542525, 37.8689695]},
#   'address': '2315',
#   'context': [{'id': 'neighborhood.595160300',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJM2xzN0E',
#     'text': 'South Campus'},
#    {'id': 'postcode.795769205773300', 'text': '94704'},
#    {'id': 'place.25790700',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#     'wikidata': 'Q484678',
#     'text': 'Berkeley'},
#    {'id': 'district.214764',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'neighborhood.595160300',
#   'type': 'Feature',
#   'place_type': ['neighborhood'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpJM2xzN0E'},
#   'text': 'South Campus',
#   'place_name': 'South Campus, Berkeley, California, United States',
#   'bbox': [-122.2659912, 37.8642502, -122.2504578, 37.8696022],
#   'center': [-122.258196, 37.866756],
#   'geometry': {'type': 'Point', 'coordinates': [-122.258196, 37.866756]},
#   'context': [{'id': 'postcode.795769205773300', 'text': '94704'},
#    {'id': 'place.25790700',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#     'wikidata': 'Q484678',
#     'text': 'Berkeley'},
#    {'id': 'district.214764',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'postcode.795769205773300',
#   'type': 'Feature',
#   'place_type': ['postcode'],
#   'relevance': 1,
#   'properties': {},
#   'text': '94704',
#   'place_name': 'Berkeley, California 94704, United States',
#   'center': [-122.252942, 37.8527315],
#   'geometry': {'type': 'Point', 'coordinates': [-122.252942, 37.8527315]},
#   'context': [{'id': 'place.25790700',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#     'wikidata': 'Q484678',
#     'text': 'Berkeley'},
#    {'id': 'district.214764',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'place.25790700',
#   'type': 'Feature',
#   'place_type': ['place'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpBWW1JN0E',
#    'wikidata': 'Q484678'},
#   'text': 'Berkeley',
#   'place_name': 'Berkeley, California, United States',
#   'bbox': [-122.3595275, 37.8412839, -122.214001, 37.906825],
#   'center': [-122.272863, 37.870839],
#   'geometry': {'type': 'Point', 'coordinates': [-122.272863, 37.870839]},
#   'context': [{'id': 'district.214764',
#     'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz',
#     'wikidata': 'Q107146',
#     'text': 'Alameda County'},
#    {'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'district.214764',
#   'type': 'Feature',
#   'place_type': ['district'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpBMGJz', 'wikidata': 'Q107146'},
#   'text': 'Alameda County',
#   'place_name': 'Alameda County, California, United States',
#   'bbox': [-122.3595275, 37.454186, -121.469275, 37.905824],
#   'center': [-121.899142, 37.609029],
#   'geometry': {'type': 'Point', 'coordinates': [-121.899142, 37.609029]},
#   'context': [{'id': 'region.419052',
#     'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#     'wikidata': 'Q99',
#     'short_code': 'US-CA',
#     'text': 'California'},
#    {'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'region.419052',
#   'type': 'Feature',
#   'place_type': ['region'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpCbVRz',
#    'wikidata': 'Q99',
#    'short_code': 'US-CA'},
#   'text': 'California',
#   'place_name': 'California, United States',
#   'bbox': [-124.5129241, 32.534251, -114.131211, 42.009503],
#   'center': [-119.699375153073, 37.0743595873945],
#   'geometry': {'type': 'Point',
#    'coordinates': [-119.699375153073, 37.0743595873945]},
#   'context': [{'id': 'country.8940',
#     'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#     'wikidata': 'Q30',
#     'short_code': 'us',
#     'text': 'United States'}]},
#  {'id': 'country.8940',
#   'type': 'Feature',
#   'place_type': ['country'],
#   'relevance': 1,
#   'properties': {'mapbox_id': 'dXJuOm1ieHBsYzpJdXc',
#    'wikidata': 'Q30',
#    'short_code': 'us'},
#   'text': 'United States',
#   'place_name': 'United States',
#   'bbox': [-179.9, 18.8164227, -66.8847656, 71.420291],
#   'center': [-97.9222112121185, 39.3812661305678],
#   'geometry': {'type': 'Point',
#    'coordinates': [-97.9222112121185, 39.3812661305678]}}]

# %%
for f in features:
    print('{place_type[0]}'.format(**f) + ':', '{place_name}'.format(**f))
# Out:
# address: 2315 College Avenue, Berkeley, California 94704, United States
# neighborhood: South Campus, Berkeley, California, United States
# postcode: Berkeley, California 94704, United States
# place: Berkeley, California, United States
# district: Alameda County, California, United States
# region: California, United States
# country: United States

# %% [markdown]
# ## 3.3 Geocoding with Nominatim

# %% [markdown]
# Open source rules! Nominatim is an open source geocoding platform that is managed by OpenStreetMap (I think). Try using the Nominatim API to geocode or reverse geocode some data of interest! You can find the Nominamtim docs [here](https://nominatim.org/release-docs/develop/api/Search/)
#
# Hint: whenever you're using an API for the first time, its always a good idea to start by trying to find some example queries in the documentation, and then tweaking them to meet your needs.

# %%
query_str = 'wurster hall'
url = "https://nominatim.openstreetmap.org/?addressdetails=1&q={0}&format=json&limit=1".format(query_str)
res = requests.get(url)

# %%
res.json()
# Out:
# [{'place_id': 311988044,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 6415953,
#   'lat': '37.87058195',
#   'lon': '-122.25490130888858',
#   'class': 'building',
#   'type': 'university',
#   'place_rank': 30,
#   'importance': 9.99999999995449e-06,
#   'addresstype': 'building',
#   'name': 'Bauer Wurster Hall',
#   'display_name': 'Bauer Wurster Hall, Ong & Ong Plaza, Southside, Berkeley, Alameda County, California, 94720, United States',
#   'address': {'building': 'Bauer Wurster Hall',
#    'road': 'Ong & Ong Plaza',
#    'neighbourhood': 'Southside',
#    'city': 'Berkeley',
#    'county': 'Alameda County',
#    'state': 'California',
#    'ISO3166-2-lvl4': 'US-CA',
#    'postcode': '94720',
#    'country': 'United States',
#    'country_code': 'us'},
#   'boundingbox': ['37.8701170', '37.8710312', '-122.2552795', '-122.2543100']}]

# %% [markdown]
# ## 3.4. Reverse geocoding with the FCC API
#
# Let's load the Craigslist rental listings again and quickly clean it up using the same code we previously used:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/bay.csv')

# clean price and neighborhood
df.price = df.price.str.strip('$').astype('float64')
df.neighborhood = df.neighborhood.str.strip().str.strip('(').str.strip(')')

# break out the date into month day year columns
df['month'] = df['date'].str.split().str[0]
df['day'] = df['date'].str.split().str[1].astype('int32')
df['year'] = df['date'].str.split().str[2].astype('int32')
del df['date']

# extract bedrooms and square footage
def clean_bdrm(value):

    if isinstance(value, str):
        end = value.find('br')

        if end == -1:
            return
        
        else:
            start = value.find('/') + 2
            return int(value[start:end])

    else:
        return
    
def clean_sqft(value):

    if isinstance(value, str):
        end = value.find('ft')
        
        if end == -1:
            return

        else:
            if value.find('br') == -1:
                start = value.find('/') + 2
            else:
                start = value.find('-') + 2

            return int(value[start:end])

    else:
        return
    
df['sqft'] = df['beds_sqft'].map(clean_sqft)
df['bedrooms'] = df['beds_sqft'].map(clean_bdrm)
df.head()
# Out:
#          neighborhood                                              title  \
# 0             bayview     Take A TOUR ON OUR ONE FURNISHED BEDROOM TODAY
# 1             bayview   Only walking distance to major shopping centers.
# 2             bayview  furnished - 1 Bedroom(s), 1 Bath(s), Air Condi...
# 3  financial district  *NEW* Beautiful, Upscale Condo in Historic Jac...
# 4   visitacion valley                                             楼上全层3房
#
#     price                 beds_sqft         pid   longitude subregion  \
# 0   950.0               / 1br -      4076905111 -122.396965        SF
# 1   950.0               / 1br -      4076901755 -122.396793        SF
# 2   950.0               / 1br -      4076899340 -122.397100        SF
# 3  3300.0      / 1br - 830ft² -      4067393707 -122.399747        SF
# 4  2000.0     / 3br - 1280ft² -      4076901071         NaN        SF
#
#                        link   latitude month  day  year    sqft  bedrooms
# 0  /sfc/apa/4076905111.html  37.761216   Sep   18  2013     NaN       1.0
# 1  /sfc/apa/4076901755.html  37.761080   Sep   18  2013     NaN       1.0
# 2  /sfc/apa/4076899340.html  37.762100   Sep   18  2013     NaN       1.0
# 3  /sfc/apa/4067393707.html  37.798108   Sep   18  2013   830.0       1.0
# 4  /sfc/apa/4076901071.html        NaN   Sep   18  2013  1280.0       3.0

# %% [markdown]
# And now let's use the FCC [Census Block Conversions API](https://geo.fcc.gov/api/census/) to turn lat/long into a block FIPS code. FIPS codes contain from left to right: the location's 2-digit state code, 3-digit county code, 6-digit census tract code, and 4-digit census block code (the first digit of which is the census block group code). With a FIPS code in hand, you can easily merge your data against Census records.
#
# Here's a sample API query to get you started:

# %%
lat = 37.761216
lon = -122.396965
url = 'https://geo.fcc.gov/api/census/block/find?latitude={0}&longitude={1}&format=json'.format(lat, lon)
response = requests.get(url)
data = response.json()
data
# Out:
# {'messages': ["FCC0001: The coordinate lies on the boundary of mulitple blocks, the block contains the clicked location is selected. For a complete list use showall=true to display 'intersection' element in the Block"],
#  'Block': {'FIPS': '060750227022007',
#   'bbox': [-122.397372, 37.759967, -122.396284, 37.7613]},
#  'County': {'FIPS': '06075', 'name': 'San Francisco County'},
#  'State': {'FIPS': '06', 'code': 'CA', 'name': 'California'},
#  'status': 'OK',
#  'executionTime': '0'}

# %% [markdown]
# ## 3.5. Exercise
#
# Your job now is to write some Python code to get the FIPS code for every row in the Craigslist rental data, and store that FIPS code as a new column in the dataframe. You might consider using [`df.iterrows()`](http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.iterrows.html) to loop through each row of the dataframe one at a time, or if you're feeling fancy, you could define a function and use a vectorized approach (e.g. `df.apply()` or `df.map()`) to run the function on each row of your dataframe without any loops at all!
#
# **CAUTION: PLEASE DO NOT RUN THIS IN CLASS!!!** If we are all doing this at the same time on the same internet connection, you might get our IP address blacklisted by querying the API too many times.
#
# A few tips:
# - Since the API is SLOW for processing a lot of records, and works one record at a time, test out your code using only a few records until you are positive you have it working correctly. It may take several minutes to grind through all the records. You might want to print the row you are processing...maybe every 10th row, to give you some sense of how it is progressing.
# - Watch out for those missing lat-longs. You'll probably want to skip them since the API won't know what to do with them.
# - Consider adding some conditional logic to handle failed HTTP requests. This will prevent you from having to start your iteration over every time your program encounters an error

# %% [markdown]
# # 4. The Census API

# %% [markdown]
# Whatever "Urban Informatics" is or isn't, more often than not you'll find it useful to refer to census data. In this course, we'll be looking at capital-C Census data, i.e. the US Census, if for no other reason than the fact that it is being taught at UC Berkeley which happens to be located in California which happens to be located in the United States. Also, US Census data rocks!
#
# **Question**: Does anyone know of other countries that have good, publically available census data?

# %% [markdown]
# The US Census provides API endpoints for most of its public data. You can find a list of them, along with links to their documentation, [here](https://www.census.gov/data/developers/data-sets.html).
#
# You can use those endpoints to construct your own custom queries and get the data you want by sending HTTP requests to those URLs. For example, to get the total population from 2018 in Alameda County, you can do:

# %%
# define parameters of our API query
acs_var = 'B01001_001E'  # total pop
state = '06'  # CA
counties = ['001', '075']  # Alameda and SF
year = 2018

# format the URL
counties_str = ','.join(counties)
url = "https://api.census.gov/data/{0}/acs/acs5?get={1}&for=county:{2}&in=state:{3}".format(
    year, acs_var, counties_str, state)

# execute the HTTP request
res = requests.get(url)
pd.DataFrame(res.json())
# Out:
#              0      1       2
# 0  B01001_001E  state  county
# 1       870044     06     075
# 2      1643700     06     001

# %% [markdown]
# ## 4.1. Getting a Census API key
# A word of warning. These Census API queries may or may not work for you without specifying an API key. It's probably a good idea to get one anyways, because you will eventually be asked for it after enough queries. You can do that [here](https://api.census.gov/data/key_signup.html)

# %% [markdown]
# ## 4.2. Census API Python Library

# %% [markdown]
# One of the great things about working with open source software and open data is that people are publishing useful tools all the time that you can use to make your life easier. In the case of Census data, there are multiple Python libraries to choose from which are designed to make it a little easier to interact with the Census API.
#
# We'll focus on one that's simply called [census](https://github.com/datamade/census). You _will_ need a Census API key to use this package.
#
# Use the instructions on that GitHub repo to use `pip` to install the `census` package, along with its sister package `us`.

# %%
from census import Census
from us import states

# I store my API key stored as an environment variable rather than a .json file
census_key = os.getenv("CENSUS_API")  

c = Census(census_key, year=year)
res = c.acs5.get((
    'NAME', acs_var), {
    'for': 'county:{}'.format(counties_str),
    'in': 'state:{}'.format(states.CA.fips)
})

pd.DataFrame(res)

# %%
acs_df = pd.DataFrame()

for year in range(2010, 2018):
    c = Census(census_key, year=year)
    res = c.acs1.get((
        'NAME', acs_var), {
        'for': 'county:{}'.format(counties_str),
        'in': 'state:{}'.format(states.CA.fips)
    })

    year_df = pd.DataFrame(res)
    year_df['year'] = year
    acs_df = pd.concat((acs_df, year_df), ignore_index=True)

# %%
import seaborn as sns
sns.lineplot(data=acs_df, x='year', y=acs_var, hue='NAME')

# %% [markdown]
# ## 4.3 More exercises!
#
# Your turn:
# 1. Look up the latitude and longitude of your home address using forward geocoding
# 2. Use the latitude and longitude from that to get the census block of your home address
# 3. Challenge problem: create a dataframe with 3 street addresses and a description column with labels for these locations, and write code that will iterate through them, get the latitude and longitude for each, and the FIPS block code, County name, and write these addresses, lat and long, and FIPS Block code and County names to a dataframe.

# %%
# %%html
# <iframe style="border-radius:12px" src="https://open.spotify.com/embed/track/4KBULZasCMBDKHY8IPUCML?utm_source=generator" width="40%" height="80" frameBorder="0" allowfullscreen="" allow="autoplay; clipboard-write; encrypted-media; fullscreen; picture-in-picture"></iframe>

# %% [markdown]
# # 5. Summary

# %% [markdown]
# By this point in the class you have all the tools you need to:
# 1. find interesting data sets
# 1. load them into Python
# 1. explore, clean, and manipulate that data
# 1. combine it with external administrative or demographic data from the Census
# 1. create charts and visualizations to communicate your findings
# 1. save your new data to disk so you can come back to it later

# %% [markdown]
# # 6. For next time

# %% [markdown]
# - We're about to enter my favorite module of this course: **Working with Geospatial Data**. Some of you have considerable experience with GIS already, and are very comfortable with concepts like coordinate reference systems and map projections, and how to deal with these when working with spatial data.  If so, you might not need to spend much time with the readings for next session, but if not, please at least familiarize yourself with the material from the first two links on the syllabus:
#   - [mapschool.io](https://mapschool.io/)
#   - Part I of [Geographic Data Science with Python](https://geographicdata.science/book/notebooks/00_toc.html)
#
# - We will also be using the GeoPandas Python library, so browse the documentation [here](http://geopandas.org/) and install it ahead of time.
# - Work through the exercises in this notebook that you didn't get through in class

# %% [markdown]
# # 7. Questions?

# %% [markdown]
# # Sources
#
# This notebook was heavily adapted from previous course material by [Prof. Paul Waddell](https://urbansim.com/people) and [Samuel Maurer](http://samuelmaurer.info/).
